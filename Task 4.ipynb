# %% [markdown]
# # The SPARKS FOUNDATION

# %% [markdown]
# # Graduate Rotational  Internship Program

# %% [markdown]
# # Task 4 - Exploratory Data Analysis - Terrorism

# %%
pip install folium
# Out:
# Collecting foliumNote: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\win8.1\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\win8.1\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\win8.1\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\win8.1\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\win8.1\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\win8.1\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\win8.1\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\win8.1\anaconda3\lib\site-packages)
#   Using cached folium-0.14.0-py2.py3-none-any.whl (102 kB)
# Requirement already satisfied: requests in c:\users\win8.1\anaconda3\lib\site-packages (from folium) (2.26.0)
# Requirement already satisfied: jinja2>=2.9 in c:\users\win8.1\anaconda3\lib\site-packages (from folium) (3.1.2)
# Collecting branca>=0.6.0
#   Using cached branca-0.6.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: numpy in c:\users\win8.1\anaconda3\lib\site-packages (from folium) (1.20.3)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\win8.1\anaconda3\lib\site-packages (from jinja2>=2.9->folium) (2.1.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\win8.1\anaconda3\lib\site-packages (from requests->folium) (3.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\win8.1\anaconda3\lib\site-packages (from requests->folium) (1.26.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\win8.1\anaconda3\lib\site-packages (from requests->folium) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\win8.1\anaconda3\lib\site-packages (from requests->folium) (2022.12.7)
# Installing collected packages: branca, folium
# Successfully installed branca-0.6.0 folium-0.14.0

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import folium
from folium.plugins import MarkerCluster

# %%
df = pd.read_csv("F:\Spark\globalterrorismdb_0718dist.csv",encoding='latin1')
# Out:
# C:\Users\win8.1\AppData\Local\Temp/ipykernel_3956/3558960389.py:1: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("F:\Spark\globalterrorismdb_0718dist.csv",encoding='latin1')

# %%
df.head().style.background_gradient()
# Out:
# C:\Users\win8.1\anaconda3\lib\site-packages\pandas\io\formats\style.py:3555: RuntimeWarning: All-NaN slice encountered
#   smin = np.nanmin(gmap) if vmin is None else vmin
# C:\Users\win8.1\anaconda3\lib\site-packages\pandas\io\formats\style.py:3556: RuntimeWarning: All-NaN slice encountered
#   smax = np.nanmax(gmap) if vmax is None else vmax
# <style type="text/css">
# #T_725b8_row0_col0, #T_725b8_row0_col1, #T_725b8_row0_col5, #T_725b8_row0_col7, #T_725b8_row0_col15, #T_725b8_row0_col16, #T_725b8_row0_col19, #T_725b8_row0_col20, #T_725b8_row0_col21, #T_725b8_row0_col25, #T_725b8_row0_col26, #T_725b8_row0_col27, #T_725b8_row0_col28, #T_725b8_row0_col65, #T_725b8_row0_col68, #T_725b8_row0_col69, #T_725b8_row0_col83, #T_725b8_row0_col101, #T_725b8_row0_col104, #T_725b8_row0_col109, #T_725b8_row0_col110, #T_725b8_row0_col111, #T_725b8_row0_col116, #T_725b8_row0_col117, #T_725b8_row0_col132, #T_725b8_row0_col133, #T_725b8_row1_col0, #T_725b8_row1_col1, #T_725b8_row1_col2, #T_725b8_row1_col3, #T_725b8_row1_col5, #T_725b8_row1_col9, #T_725b8_row1_col14, #T_725b8_row1_col15, #T_725b8_row1_col16, #T_725b8_row1_col19, #T_725b8_row1_col20, #T_725b8_row1_col21, #T_725b8_row1_col25, #T_725b8_row1_col26, #T_725b8_row1_col27, #T_725b8_row1_col34, #T_725b8_row1_col36, #T_725b8_row1_col40, #T_725b8_row1_col65, #T_725b8_row1_col68, #T_725b8_row1_col69, #T_725b8_row1_col83, #T_725
, #T_d5e44_row3_col40, #T_d5e44_row3_col41, #T_d5e44_row3_col42, #T_d5e44_row3_col43, #T_d5e44_row3_col44, #T_d5e44_row3_col45, #T_d5e44_row3_col46, #T_d5e44_row3_col47, #T_d5e44_row3_col48, #T_d5e44_row3_col49, #T_d5e44_row3_col51, #T_d5e44_row3_col52, #T_d5e44_row3_col53, #T_d5e44_row3_col54, #T_d5e44_row3_col55, #T_d5e44_row3_col56, #T_d5e44_row3_col57, #T_d5e44_row3_col58, #T_d5e44_row3_col59, #T_d5e44_row3_col60, #T_d5e44_row3_col61, #T_d5e44_row3_col62, #T_d5e44_row3_col63, #T_d5e44_row3_col64, #T_d5e44_row3_col65, #T_d5e44_row3_col66, #T_d5e44_row3_col67, #T_d5e44_row3_col68, #T_d5e44_row3_col69, #T_d5e44_row3_col70, #T_d5e44_row3_col71, #T_d5e44_row3_col72, #T_d5e44_row3_col73, #T_d5e44_row3_col74, #T_d5e44_row3_col75, #T_d5e44_row3_col76, #T_d5e44_row4 ...

# %%
df.corr().style.background_gradient()
# Out:
# <style type="text/css">
# #T_3a48e_row0_col0, #T_3a48e_row0_col1, #T_3a48e_row1_col0, #T_3a48e_row1_col1, #T_3a48e_row2_col2, #T_3a48e_row3_col3, #T_3a48e_row4_col4, #T_3a48e_row5_col5, #T_3a48e_row6_col6, #T_3a48e_row7_col7, #T_3a48e_row8_col8, #T_3a48e_row9_col9, #T_3a48e_row10_col10, #T_3a48e_row11_col11, #T_3a48e_row12_col12, #T_3a48e_row13_col13, #T_3a48e_row14_col14, #T_3a48e_row15_col15, #T_3a48e_row16_col16, #T_3a48e_row17_col17, #T_3a48e_row18_col18, #T_3a48e_row19_col19, #T_3a48e_row20_col20, #T_3a48e_row21_col21, #T_3a48e_row22_col22, #T_3a48e_row23_col23, #T_3a48e_row24_col24, #T_3a48e_row25_col25, #T_3a48e_row25_col51, #T_3a48e_row26_col26, #T_3a48e_row26_col51, #T_3a48e_row27_col27, #T_3a48e_row27_col51, #T_3a48e_row28_col28, #T_3a48e_row29_col29, #T_3a48e_row30_col30, #T_3a48e_row31_col31, #T_3a48e_row32_col32, #T_3a48e_row33_col33, #T_3a48e_row34_col34, #T_3a48e_row35_col35, #T_3a48e_row36_col36, #T_3a48e_row37_col37, #T_3a48e_row38_col38, #T_3a48e_row39_col39, #T_3a48e_row40_col40, #T_3a48e_row41_col41, #T_3a48e_row42_col42, #T_3a48e_row43_col43, #T_3a48e_row44_col44, #T_3a48e_row45_col45, #T_3a48e_row46_col46, #T_3a48e_row47_col47, #T_3a48e_row48_col48, #T_3a48e_row49_col49, #T_3a48e_row50_col50, #T_3a48e_row51_col25, #T_3a48e_row51_col26, #T_3a48e_row51_col27, #T_3a48e_row51_col51, #T_3a48e_row52_col52, #T_3a48e_row53_col53, #T_3a48e_row54_col54, #T_3a48e_row55_col55, #T_3a48e_row56_col56, #T_3a48e_row57_col57, #T_3a48e_row58_col58, #T_3a48e_row59_col59, #T_3a48e_row60_col60, #T_3a48e_row61_col61, #T_3a48e_row62_col62, #T_3a48e_row63_col63, #T_3a48e_row64_col64, #T_3a48e_row65_col65, #T_3a48e_row66_col66, #T_3a48e_row67_col67, #T_3a48e_row68_col68, #T_3a48e_row69_col69, #T_3a48e_row70_col70, #T_3a48e_row71_col71, #T_3a48e_row72_col72, #T_3a48e_row73_col73, #T_3a48e_row73_col74, #T_3a48e_row74_col73, #T_3a48e_row74_col74, #T_3a48e_row75_col75, #T_3a48e_row76_col76 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T
48e_row58_col52, #T_3a48e_row60_col22, #T_3a48e_row63_col10, #T_3a48e_row63_col22, #T_3a48e_row64_col10, #T_3a48e_row64_col26, #T_3a48e_row64_col44, #T_3a48e_row64_col49, #T_3a48e_row65_col23, #T_3a48e_row65_col31, #T_3a48e_row70_col37, #T_3a48e_row72_col34, #T_3a48e_row75_col63, #T_3a48e_row76_col45 {
#   background-color: #f1ebf4;
#   color: #000000;
# }
# #T_3a48e_row0_col6, #T_3a48e_row0_col43, #T_3a48e_row1_col6, #T_3a48e_row1_col43, #T_3a48e_row2_col29, #T_3a48e_row10_col29, #T_3a48e_row22_col49, #T_3a48e_row43_col28, #T_3a48e_row43_col30, #T_3a48e_row50_col23, #T_3a48e_row50_col72, #T_3a48e_row59_col68, #T_3a48e_row63_col30, #T_3a48e_row66_col30, #T_3a48e_row70_col28, #T_3a48e_row70_col64 {
#   background-color: #67a4cc;
#   color: #f1f1f1;
# }
# #T_3a48e_row0_col7, #T_3a48e_row1_col7, #T_3a48e_row2_col15, #T_3a48e_row2_col43, #T_3a48e_row4_col62, #T_3a48e_row5_col6, #T_3a48e_row6_col12, #T_3a48e_row7_col62, #T_3a48e_row10_col50, #T_3a48e_row12_col65, #T_3a48e_row14_col15, #T_3a48e_row14_col76, #T_3a48e_row17_col12, #T_3a48e_row17_col48, #T_3a48e_row17_col62, #T_3a48e_row18_col37, #T_3a48e_row19_col72, #T_3a48e_row21_col60, #T_3a48e_row21_col72, #T_3a48e_row24_col6, #T_3a48e_row24_col64, #T_3a48e_row25_col37, #T_3a48e_row26_col49, #T_3a48e_row27

# %% [markdown]
#  # We are checking null values

# %%
import seaborn as sns
sns.heatmap(df.isnull(),cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
df.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %% [markdown]
# US Terror Attacks and Death Injuries

# %%
df.nkillus.plot(kind = 'line', color = 'red', label = 'The Number of Total Confirmed Fatalities for US', linewidth = 2, alpha = 0.8, grid = True, 
                 linestyle = ':', figsize = (20,20), fontsize=15)
df.nwoundus.plot(color = "green", label = 'The Number of Confirmed Non-Fatal Injuries for US', linewidth = 2, alpha = 0.8, grid = True, 
                 linestyle = '-.', figsize = (20,20), fontsize=15)

plt.legend(loc='upper right')     # legend = puts label into plot
plt.xlabel('Database Index', fontsize=10)              # label = name of label
plt.ylabel('Number of Dead or Injuries', fontsize=15)

plt.title('Confirmed Fatalities & Non-Fatal Injuries for US')            #plot title
plt.show()

# %% [markdown]
# Given that the data is sorted by dates, attacks on US citizens seem to be very rare in a given date range. But the terrorist act against the citizens of US has been increasingly in the following year after this rare date range. By finding the date of the start of the increase, the factors in increasing terrorist acts can be easily identified by taking into account the changes and developments in the country after this date.

# %% [markdown]
# Death and Injuries at all time

# %%
df.plot(kind = 'scatter', x = 'nkill', y = 'nwound', alpha = 0.5, color = 'red', figsize = (20,20), fontsize=15)
plt.xlabel('Kill', fontsize=15)
plt.ylabel('Wound', fontsize=15)
plt.title('Kill - Wound Scatter Plot')
plt.show()

# %% [markdown]
# In the majority of acts of terrorism, the mortality rate and injuries were low, but a small number of actions led to too many deaths and injuries.

# %% [markdown]
# Frequency of Terrorist Actions in Customized Region
# Let's analyze in Middle East and North Africa

# %%
middleEastData = df[df['region'] == 10]
middleEastData.iyear.plot(kind = 'hist', bins = 30, figsize = (20,20), color = 'red', fontsize=15)
plt.xlabel('Year', fontsize=15)
plt.ylabel('Frequency', fontsize=15)
plt.title('Frequency of Middle East & North Africa Terrorism Actions by Years')
plt.show()

# %% [markdown]
# Terrorist attacks have increased in recent years.

# %%
df.nkillus.plot(kind = 'line', color = 'red', label = 'People Dead of Terrorism in the World', linewidth = 1.5, alpha = 0.8, grid = True, 
                 linestyle = ':', figsize = (20,20), fontsize=15)
middleEastData.nkillus.plot(color = "green", label = 'People Dead of Terrorism in the Middle East & North Africa', linewidth = 1.5, alpha = 0.8, 
                            grid = True, linestyle = '-.', figsize = (20,20), fontsize=15)

plt.legend(loc='upper right')     # legend = puts label into plot
plt.xlabel('Database Index', fontsize=15)              # label = name of label
plt.ylabel('Number of Dead', fontsize=15)

plt.title('Comparing those who died in terror attacks in the World and Middle East & North Africa')            #plot title
plt.show()

# %% [markdown]
# Terrorist Attacks of a Particular year and their Locations.
# Let's look at the terrorist acts in the world over a certain year.

# %%
filterYear = df['iyear'] == 1970

# %%
filterData = df[filterYear] # filter data
# filterData.info()
reqFilterData = filterData.loc[:,'city':'longitude'] #We are getting the required fields
reqFilterData = reqFilterData.dropna() # drop NaN values in latitude and longitude
reqFilterDataList = reqFilterData.values.tolist()
# reqFilterDataList

# %%
map = folium.Map(location = [0, 30], tiles='CartoDB positron', zoom_start=2)
# clustered marker
markerCluster = folium.plugins.MarkerCluster().add_to(map)
for point in range(0, len(reqFilterDataList)):
    folium.Marker(location=[reqFilterDataList[point][1],reqFilterDataList[point][2]], popup = reqFilterDataList[point][0]).add_to(markerCluster)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ff5d7ed2eedf263fc55ff75f0deecbf2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ff5d7ed2eedf263fc55ff75f0deecbf2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ff5d7ed2eedf263fc55ff75f0deecbf2 = L.map(
#                 &quot;map_ff5d7ed2eedf263fc55ff75f0deecbf2&quot;,
#                 {
#                     center: [0.0, 30.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e748f7e817681c66f0d103599397e820 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ff5d7ed2eedf263fc55ff75f0deecbf2);
#
#
#             var marker_cluster_5f1744ddc247c4142416cdef97cf2d6e = L.markerClusterGroup(
#                 {}
#             );
#             map_ff5d7ed2eedf263fc55ff75f0deecbf2.addLayer(marker_cluster_5f1744ddc247c4142416cdef97cf2d6e);
#
#
#             var marker_c14d83ecd0180962d1a616a2b5a345e8 = L.marker(
#                 [18.456792, -69.951164],
#                 {}
#             ).addTo(marker_cluster_5f1744ddc247c4142416cdef97cf2d6e);
#
#
#         var popup_31d6201eecd240be41956982ec7f9e7e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c0416551ec6aa10588aba28c8c969de3 = $(`&lt;div id=&quot;html_c0416551ec6aa10588aba28c8c969de3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Santo Domingo&lt;/div&gt;`)[0];
#                 popup_31d6201eecd240be41956982ec7f9e7e.setContent(html_c0416551ec6aa10588aba28c8c969de3);
#
#
#
#         marker_c14d83ecd0180962d1a616a2b5a345e8.bindPopup(popup_31d6201eecd240be41956982ec7f9e7e)
#         ;
#
#
#
#
#             var marker_fdbf484a5c80446ebd6edcc980010632 = L.marker(
#                 [19.371887, -99.086624],
#                 {}
#             ).addTo(marker_cluster_5f1744ddc247c4142416cdef97cf2d6e);
#
#
#         var popup_e6f05cabb8f31cc66af03bf4a1a2d3a0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_941a049b036a624cb765a253c6119c73 = $(`&lt;div id=&quot;html_941a049b036a624cb765a253c6119c73&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Mexico city&lt;/div&gt;`)[0];
#                 popup_e6f05cabb8f31cc66af03bf4a1a2d3a0.setContent(html_941a049b036a624cb765a253c6119c73);
#
#
#
#         marker_fdbf484a5c80446ebd6edcc980010632.bindPopup(popup_e6f05cabb8f31cc66af03bf4a1a2d3a0)
#         ;
#
#
#
#
#             var marker_ed3c0247ff9519edd38054a90d4c78fc = L.marker(
#                 [15.478598, 120.599741],
#                 {}
#             ).addTo(marker_cluster_5f1744ddc247c4142416cdef97cf2d6e);
#
#
#         var popup_25624f71e3ac1c9f85b9095305f65ce7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_53205075b7a824a3f3989b346c67b15b = $(`&lt;div id=&quot;html_53205075b7a824a3f3989b346c67b15b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Unknown&lt;/div&gt;`)[0];
#                 popup_25624f71e3ac1c9f85b9095305f65ce7.setContent(html_53205075b7a824a3f3989b346c67b15b);
#
#
#
#         marker_ed3c0247ff9519edd38054a90d4c78fc.bindPopup(popup_25624f71e3ac1c9f85b9095305f65ce7)
#         ;
#
#
#
#
#             var marker_0d88e4acc59b524d993c316a0b832df1 = L.marker(
#                 [37.99749, 23.762728],
#                 {}
#             ).addTo(marker_cluster_5f1744ddc247c4142416cdef97cf2d6e);
#
#
#         var popup_1d25d847735783c286d1d42e8343dff6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_304248b86c7a166ec39b7e7ca7507a4b = $(`&lt;div id=&quot;html_304248b86c7a166ec39b7e7ca7507a4b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Athens&lt;/div&gt;`)[0];
#                 popup_1d25d847735783c286d1d42e8343dff6.setContent(html_304248b86c7a166ec39b7e7ca7507a4b);
#
#
#
#         marker_0d88e4acc59b524d993c316a0b832df1.bindPopup(popup_1d25d847735783c286d1d42e8343dff6)
#         ;
#
#
#
#
#             var marker_e4d4568d0e60

# %% [markdown]
# 84% of the terrorist attacks in 1970 were carried out on the American continent. In 1970, the Middle East and North Africa, currently the center of wars and terrorist attacks, faced only one terrorist attack.

# %%
#### Total Number of people killed in terror attack

# %%
killData = df.loc[:,'nkill']
print('Number of people killed by terror attack:', int(sum(killData.dropna())))# drop the NaN values
# Out:
# Number of people killed by terror attack: 411868

# %% [markdown]
# Let's look at what types of attacks these deaths were made of.

# %%
attackData = df.loc[:,'attacktype1':'attacktype1_txt']
# attackData
typeKillData = pd.concat([attackData, killData], axis=1)

# %%
typeKillFormatData = typeKillData.pivot_table(columns='attacktype1_txt', values='nkill', aggfunc='sum')
typeKillFormatData
# Out:
# attacktype1_txt  Armed Assault  Assassination  Bombing/Explosion  \
# nkill                 160297.0        24920.0           157321.0
#
# attacktype1_txt  Facility/Infrastructure Attack  Hijacking  \
# nkill                                    3642.0     3718.0
#
# attacktype1_txt  Hostage Taking (Barricade Incident)  \
# nkill                                         4478.0
#
# attacktype1_txt  Hostage Taking (Kidnapping)  Unarmed Assault  Unknown
# nkill                                24231.0            880.0  32381.0

# %%
typeKillFormatData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1 entries, nkill to nkill
# Data columns (total 9 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Armed Assault                        1 non-null      float64
#  1   Assassination                        1 non-null      float64
#  2   Bombing/Explosion                    1 non-null      float64
#  3   Facility/Infrastructure Attack       1 non-null      float64
#  4   Hijacking                            1 non-null      float64
#  5   Hostage Taking (Barricade Incident)  1 non-null      float64
#  6   Hostage Taking (Kidnapping)          1 non-null      float64
#  7   Unarmed Assault                      1 non-null      float64
#  8   Unknown                              1 non-null      float64
# dtypes: float64(9)
# memory usage: 80.0+ bytes

# %%
labels = typeKillFormatData.columns.tolist() # convert line to list
transposed = typeKillFormatData.T # transpose
values = transposed.values.tolist()
values = [val[0] for val in values]  # Extracting the first element from each sublist

fig, ax = plt.subplots(figsize=(20, 20), subplot_kw=dict(aspect="equal"))
plt.pie(values, startangle=90, autopct='%.2f%%')
plt.title('Types of terrorist attacks that cause deaths')
plt.legend(labels, loc='upper right', bbox_to_anchor=(1.3, 0.9), fontsize=15) # location legend
plt.show()

# %% [markdown]
# Armed assault and bombing/explosion are seen to be the cause of 77% of the deaths in these attacks. This rate is why these attacks are used so many times in terrorist actions. This is how dangerous weapons and explosives are to the world.

# %% [markdown]
# # Number of Killed in Terrorist Attacks by Countries.

# %%
countryData = df.loc[:,'country':'country_txt']
# countyData
countryKillData = pd.concat([countryData, killData], axis=1)

# %%
countryKillFormatData = countryKillData.pivot_table(columns='country_txt', values='nkill', aggfunc='sum')
countryKillFormatData
# Out:
# country_txt  Afghanistan  Albania  Algeria  Andorra  Angola  \
# nkill            39384.0     42.0  11066.0      0.0  3043.0
#
# country_txt  Antigua and Barbuda  Argentina  Armenia  Australia  Austria  ...  \
# nkill                        0.0      490.0     37.0       23.0     30.0  ...
#
# country_txt  Vietnam  Wallis and Futuna  West Bank and Gaza Strip  \
# nkill            1.0                0.0                    1500.0
#
# country_txt  West Germany (FRG)  Western Sahara   Yemen  Yugoslavia  Zaire  \
# nkill                      97.0             1.0  8776.0       119.0  324.0
#
# country_txt  Zambia  Zimbabwe
# nkill          70.0     154.0
#
# [1 rows x 205 columns]

# %%
countryKillFormatData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1 entries, nkill to nkill
# Columns: 205 entries, Afghanistan to Zimbabwe
# dtypes: float64(205)
# memory usage: 1.6+ KB

# %%
fig_size = plt.rcParams["figure.figsize"]
fig_size[0]=25
fig_size[1]=25
plt.rcParams["figure.figsize"] = fig_size

# %%
labels = countryKillFormatData.columns.tolist()
labels = labels[:50] #50 bar provides nice view
index = np.arange(len(labels))
transpoze = countryKillFormatData.T
values = transpoze.values.tolist()
values = values[:50]
values = [int(i[0]) for i in values] # convert float to int
colors = ['red', 'green', 'blue', 'purple', 'yellow', 'brown', 'black', 'gray', 'magenta', 'orange'] # color list for bar chart bar color 
fig, ax = plt.subplots(1, 1)
ax.yaxis.grid(True)
fig_size = plt.rcParams["figure.figsize"]
fig_size[0]=25
fig_size[1]=25
plt.rcParams["figure.figsize"] = fig_size
plt.bar(index, values, color = colors, width = 0.9)
plt.ylabel('Killed People', fontsize=15)
plt.xticks(index, labels, fontsize=12, rotation=90)
plt.title('Number of people killed by countries')
# print(fig_size)
plt.show()

# %%
labels = countryKillFormatData.columns.tolist()
labels = labels[50:101]
index = np.arange(len(labels))
transpoze = countryKillFormatData.T
values = transpoze.values.tolist()
values = values[50:101]
values = [int(i[0]) for i in values]
colors = ['red', 'green', 'blue', 'purple', 'yellow', 'brown', 'black', 'gray', 'magenta', 'orange']
fig, ax = plt.subplots(1, 1)
ax.yaxis.grid(True)
fig_size = plt.rcParams["figure.figsize"]
fig_size[0]=25
fig_size[1]=25
plt.rcParams["figure.figsize"] = fig_size
plt.bar(index, values, color = colors, width = 0.9)
plt.ylabel('Killed People', fontsize=15)
plt.xticks(index, labels, fontsize=12, rotation=90)
plt.title('Number of people killed by countries')
plt.show()

# %%
labels = countryKillFormatData.columns.tolist()
labels = labels[152:206]
index = np.arange(len(labels))
transpoze = countryKillFormatData.T
values = transpoze.values.tolist()
values = values[152:206]
values = [int(i[0]) for i in values]
colors = ['red', 'green', 'blue', 'purple', 'yellow', 'brown', 'black', 'gray', 'magenta', 'orange']
fig, ax = plt.subplots(1, 1)
ax.yaxis.grid(True)
fig_size = plt.rcParams["figure.figsize"]
fig_size[0]=25
fig_size[1]=25
plt.rcParams["figure.figsize"] = fig_size
plt.bar(index, values, color = colors, width = 0.9)
plt.ylabel('Killed People', fontsize=15)
plt.xticks(index, labels, fontsize=12, rotation=90)
plt.title('Number of people killed by countries')
plt.show()

# %% [markdown]
# Terrorist acts in the Middle East and northern Africa have been seen to have fatal consequences. The Middle East and North Africa are seen to be the places of serious terrorist attacks. In addition, even though there is a perception that Muslims are supporters of terrorism, Muslims are the people who are most damaged by terrorist attacks. If you look at the graphics, it appears that Iraq, Afghanistan and Pakistan are the most damaged countries. All of these countries are Muslim countries.

# %% [markdown]
# I wanted to let you know the results of my recent exploratory data analysis (EDA) work that was concerned with terrorism. As a student studying statistics and data science, this assignment gave me important new perspectives on the trends and effects of terrorist attacks.
# One of the main findings of the investigation is that, in 1970, 84% of terrorist attacks took place on the American continent, while the Middle East and North Africa, regions today noted for their high incidence of terrorism, saw just one assault. This demonstrates how the geographic distribution of terrorist actions has significantly changed over time
# In addition, it was determined that 77% of the fatalities from these incidents were mostly caused by armed assault and bombings/explosions. This highlights the serious risk that weapons and explosives used in terrorist attacks and the immediate necessity for action to stop their spread.
# Contrary to popular belief, Muslims do not support terrorism, the data also showed that the Middle East and North Africa are among the regions most harmed by terrorist acts. In actuality, the group most negatively impacted by these violent crimes is Muslims. Iraq, Afghanistan, and Pakistan, all of which are primarily Muslim countries, have all sustained substantial damage.
# I used a variety of visualisation strategies and descriptive statistics to show these results, which allowed for a thorough grasp of the data. I was able to illustrate the geographic distribution of attacks, the reasons of fatalities, and the effects on nations with a Muslim majority thanks to these pictures.
# Overall, this EDA exercise has clarified the intricate dynamics.of terrorism and its broad repercussions. It has reaffirmed the significance of data-driven analysis in acquiring knowledge and creating successful solutions to counter this international threat.
#
# I appreciate your time and assistance during my internship. In the future, I hope to share more of my work with you.
